# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"C:\Users\G VARSHIT HARIPRASAD\Desktop\Infotact Solutions Project\Month 2 - April\AI Sentiment Analysis System 2\data\complaints_Database.xlsx")

# %%
df.head()
# Out:
#   Agency                   Agency Name Problem (formerly Complaint Type)  \
# 0    DOT  Department of Transportation                  Street Condition
# 1    DOT  Department of Transportation                  Street Condition
# 2    DOT  Department of Transportation                  Street Condition
# 3    DOT  Department of Transportation                  Street Condition
# 4    DOT  Department of Transportation                  Street Condition
#
#   Problem Detail (formerly Descriptor) Additional Details
# 0                              Pothole                NaN
# 1                              Pothole                NaN
# 2                              Pothole                NaN
# 3                              Pothole                NaN
# 4                              Pothole                NaN

# %%
print(df.columns)
# Out:
# Index(['Agency', 'Agency Name', 'Problem (formerly Complaint Type)',
#        'Problem Detail (formerly Descriptor)', 'Additional Details'],
#       dtype='object')

# %%
print(df.shape)
# Out:
# (1048575, 5)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 5 columns):
#  #   Column                                Non-Null Count    Dtype
# ---  ------                                --------------    -----
#  0   Agency                                1048575 non-null  object
#  1   Agency Name                           1048575 non-null  object
#  2   Problem (formerly Complaint Type)     1048575 non-null  object
#  3   Problem Detail (formerly Descriptor)  1037561 non-null  object
#  4   Additional Details                    493657 non-null   object
# dtypes: object(5)
# memory usage: 40.0+ MB
# None

# %%
df = df.fillna("")

# %%
df.to_csv(
    r"C:\Users\G VARSHIT HARIPRASAD\Desktop\Infotact Solutions Project\Month 2 - April\AI Sentiment Analysis System 2\data/raw_dataset.csv",
    index=False
)

# %%
df.to_csv(
    r"C:\Users\G VARSHIT HARIPRASAD\Desktop\Infotact Solutions Project\Month 2 - April\AI Sentiment Analysis System 2\data/raw_dataset.csv",
    index=False
)
