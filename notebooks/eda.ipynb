# %%
# !pip install matplotlib
# !pip install seaborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_csv(r"C:\Users\G VARSHIT HARIPRASAD\Desktop\Infotact Solutions Project\Month 2 - April\AI Sentiment Analysis System 2\data\cleaned_complaints.csv")

# %%
df["Agency Name"].value_counts().head(10)
# Out:
# Agency Name
# New York City Police Department                       381209
# Department of Housing Preservation and Development    329184
# Department of Sanitation                              117328
# Department of Transportation                           82720
# Department of Environmental Protection                 48996
# Department of Buildings                                27147
# Department of Health and Mental Hygiene                17931
# Department of Parks and Recreation                     17580
# Taxi and Limousine Commission                           8868
# Department of Homeless Services                         7719
# Name: count, dtype: int64

# %%
df["Agency Name"].value_counts().head(10).plot(
    kind="bar"
)

plt.title("Top Agencies")

# Save plot

plt.savefig(
    r"outputs/top_agencies.png",
    dpi=300,
    bbox_inches='tight'
)
plt.show()

# %%
df["Problem (formerly Complaint Type)"].value_counts().head(10).plot(
    kind="bar"
)

plt.title("Top Complaint Types")

plt.savefig(
    r"C:\Users\G VARSHIT HARIPRASAD\Desktop\Infotact Solutions Project\Month 2 - April\AI Sentiment Analysis System 2\outputs\top_complaint_types",
    dpi=300,
    bbox_inches='tight'
)
plt.show()
